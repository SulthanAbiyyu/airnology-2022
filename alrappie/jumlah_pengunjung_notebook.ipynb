# %%
import pandas as pd

# %%
od_15367_jml_pengunjung_ke_objek_wisata__jenis_wisatawan = pd.read_csv('Files/pariwisata/od_15367_jml_pengunjung_ke_objek_wisata__jenis_wisatawan/data.jabarprov.go.id/disparbud-od_15367_jml_pengunjung_ke_objek_wisata__jenis_wisatawan_data.csv', sep=',')

od_15414_jumlah_pengunjung_museum_berdasarkan_kabupatenkota = pd.read_csv('Files/pariwisata/od_15414_jumlah_pengunjung_museum_berdasarkan_kabupatenkota/data.jabarprov.go.id/disparbud-od_15414_jumlah_pengunjung_museum_berdasarkan_kabupatenkota_data.csv')

od_15420_jml_pengunjung_tempat_rekreasi__jenis_wisatawan = pd.read_csv('Files/pariwisata/od_15420_jml_pengunjung_tempat_rekreasi__jenis_wisatawan/data.jabarprov.go.id/disparbud-od_15420_jml_pengunjung_tempat_rekreasi__jenis_wisatawan_data.csv')

od_15422_jumlah_wisatawan_berdasarkan_kategori = pd.read_csv('Files/pariwisata/od_15422_jumlah_wisatawan_berdasarkan_kategori/data.jabarprov.go.id/disparbud-od_15422_jumlah_wisatawan_berdasarkan_kategori_data.csv')

od_17233_jumlah_pengunjung_bioskop_berdasarkan_kabupatenkota = pd.read_csv('Files/pariwisata/od_17233_jumlah_pengunjung_bioskop_berdasarkan_kabupatenkota/data.jabarprov.go.id/disparbud-od_17233_jumlah_pengunjung_bioskop_berdasarkan_kabupatenkota_data.csv')

od_penginapan_remaja_berdasarkan_kunjungan_wisatawan = pd.read_csv('Files/pariwisata/od_penginapan_remaja_berdasarkan_kunjungan_wisatawan/data.jabarprov.go.id/disparbud-od_penginapan_remaja_berdasarkan_kunjungan_wisatawan_data.csv')

od_perkemahan_berdasarkan_jumlah_pengunjung = pd.read_csv('Files/pariwisata/od_perkemahan_berdasarkan_jumlah_pengunjung/data.jabarprov.go.id/disparbud-od_perkemahan_berdasarkan_jumlah_pengunjung_data.csv')

od_pondok_wisata_berdasarkan_jumlah_pengunjung = pd.read_csv('Files/pariwisata/od_pondok_wisata_berdasarkan_jumlah_pengunjung/data.jabarprov.go.id/disparbud-od_pondok_wisata_berdasarkan_jumlah_pengunjung_data.csv')

# %%
od_15367_jml_pengunjung_ke_objek_wisata__jenis_wisatawan
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3201
# 2      3             32    JAWA BARAT                 3202
# 3      4             32    JAWA BARAT                 3202
# 4      5             32    JAWA BARAT                 3203
# ..   ...            ...           ...                  ...
# 344  345             32    JAWA BARAT                 3277
# 345  346             32    JAWA BARAT                 3278
# 346  347             32    JAWA BARAT                 3278
# 347  348             32    JAWA BARAT                 3279
# 348  349             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota jenis_wisatawan  jumlah_pengunjung satuan  tahun
# 0       KABUPATEN BOGOR     MANCANEGARA              54927  ORANG   2014
# 1       KABUPATEN BOGOR       NUSANTARA            4075198  ORANG   2014
# ...

# %%
od_15414_jumlah_pengunjung_museum_berdasarkan_kabupatenkota
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 183  184             32    JAWA BARAT                 3275
# 184  185             32    JAWA BARAT                 3276
# 185  186             32    JAWA BARAT                 3277
# 186  187             32    JAWA BARAT                 3278
# 187  188             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_pengunjung satuan  tahun
# 0       KABUPATEN BOGOR                  0  ORANG   2014
# 1    KABUPATEN SUKABUMI              19011  ORANG   2014
# 2     KABUPATEN CIANJUR                  0  ORANG   2014
# ...

# %%
od_15420_jml_pengunjung_tempat_rekreasi__jenis_wisatawan
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3201
# 2      3             32    JAWA BARAT                 3202
# 3      4             32    JAWA BARAT                 3202
# 4      5             32    JAWA BARAT                 3203
# ..   ...            ...           ...                  ...
# 371  372             32    JAWA BARAT                 3277
# 372  373             32    JAWA BARAT                 3278
# 373  374             32    JAWA BARAT                 3278
# 374  375             32    JAWA BARAT                 3279
# 375  376             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota jenis_wisatawan  jumlah_pengunjung satuan  tahun
# 0       KABUPATEN BOGOR     MANCANEGARA                  0  ORANG   2014
# 1       KABUPATEN BOGOR       NUSANTARA                  0  ORANG   2014
# ...

# %%
od_17233_jumlah_pengunjung_bioskop_berdasarkan_kabupatenkota
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 103  104             32    JAWA BARAT                 3275
# 104  105             32    JAWA BARAT                 3276
# 105  106             32    JAWA BARAT                 3277
# 106  107             32    JAWA BARAT                 3278
# 107  108             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_pengunjung satuan  tahun
# 0       KABUPATEN BOGOR                  0  ORANG   2014
# 1    KABUPATEN SUKABUMI                  0  ORANG   2014
# 2     KABUPATEN CIANJUR                  0  ORANG   2014
# ...

# %%
od_penginapan_remaja_berdasarkan_kunjungan_wisatawan
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      0             32    JAWA BARAT                 3201
# 1      1             32    JAWA BARAT                 3201
# 2      2             32    JAWA BARAT                 3202
# 3      3             32    JAWA BARAT                 3202
# 4      4             32    JAWA BARAT                 3203
# ..   ...            ...           ...                  ...
# 209  209             32    JAWA BARAT                 3277
# 210  210             32    JAWA BARAT                 3278
# 211  211             32    JAWA BARAT                 3278
# 212  212             32    JAWA BARAT                 3279
# 213  213             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota jenis_wisatawan  jumlah_pengunjung satuan  tahun
# 0       KABUPATEN BOGOR     MANCANEGARA                  0  ORANG   2014
# 1       KABUPATEN BOGOR       NUSANTARA                  0  ORANG   2014
# ...

# %%
od_perkemahan_berdasarkan_jumlah_pengunjung
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      0             32    JAWA BARAT                 3201
# 1      1             32    JAWA BARAT                 3201
# 2      2             32    JAWA BARAT                 3202
# 3      3             32    JAWA BARAT                 3202
# 4      4             32    JAWA BARAT                 3203
# ..   ...            ...           ...                  ...
# 317  317             32    JAWA BARAT                 3277
# 318  318             32    JAWA BARAT                 3278
# 319  319             32    JAWA BARAT                 3278
# 320  320             32    JAWA BARAT                 3279
# 321  321             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota jenis_wisatawan  jumlah_pengunjung satuan  tahun
# 0       KABUPATEN BOGOR     MANCANEGARA                  8  ORANG   2014
# 1       KABUPATEN BOGOR       NUSANTARA              16963  ORANG   2014
# ...

# %%
od_pondok_wisata_berdasarkan_jumlah_pengunjung
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      0             32    JAWA BARAT                 3201
# 1      1             32    JAWA BARAT                 3201
# 2      2             32    JAWA BARAT                 3202
# 3      3             32    JAWA BARAT                 3202
# 4      4             32    JAWA BARAT                 3203
# ..   ...            ...           ...                  ...
# 209  209             32    JAWA BARAT                 3277
# 210  210             32    JAWA BARAT                 3278
# 211  211             32    JAWA BARAT                 3278
# 212  212             32    JAWA BARAT                 3279
# 213  213             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota jenis_wisatawan  jumlah_pengunjung satuan  tahun
# 0       KABUPATEN BOGOR     MANCANEGARA                  0  ORANG   2014
# 1       KABUPATEN BOGOR       NUSANTARA                  0  ORANG   2014
# ...

# %%
od_15422_jumlah_wisatawan_berdasarkan_kategori.groupby(['tahun','kategori_wisatawan'])['jumlah_wisatawan'].sum()
# Out:
# tahun  kategori_wisatawan
# 2016   WISATAWAN DOMESTIK       58728666
#        WISATAWAN MANCANEGARA     4428094
# 2017   WISATAWAN DOMESTIK       59644070
#        WISATAWAN MANCANEGARA     4984035
# 2018   WISATAWAN DOMESTIK       63298608
#        WISATAWAN MANCANEGARA     2597455
# 2019   WISATAWAN DOMESTIK       64610832
#        WISATAWAN MANCANEGARA     3645433
# 2020   WISATAWAN DOMESTIK       36524515
#        WISATAWAN MANCANEGARA     3716950
# Name: jumlah_wisatawan, dtype: int64

# %%
import pandas as pd

# %%
data = pd.read_csv("../../data/google_review_wisata_jabar/curug_cikaso.csv")
data.head()
# Out:
#                              nama  bintang  \
# 0                   irsadul fuadi        5
# 1                    Ahmad Ridwan        5
# 2            taruli basa christin        5
# 3               ni komang suryati        5
# 4  Anastasia Meirina Udayani Lumy        5
#
#                                             komentar
# 0                                                NaN
# 1                                                NaN
# 2  Bagus air terjun nya bisa berenang luas tempat...
# 3  2 minggu lalu abis kena bencana air bah, bangu...
# 4                                                NaN

# %%
data.dropna()
# Out:
#                       nama  bintang  \
# 2     taruli basa christin        5
# 3        ni komang suryati        5
# 6               Elisa Rine        5
# 7              Opal Raufal        5
# 8               Izy Valent        5
# ...                    ...      ...
# 1001       Windya Hertanti        5
# 1002      Isye siti Zahroh        5
# 1003      Nanang Indriyono        4
# 1008         Muhamad Dendi        5
# 1009       Andrian Purnama        5
#
#                                                komentar
# 2     Bagus air terjun nya bisa berenang luas tempat...
# 3     2 minggu lalu abis kena bencana air bah, bangu...
# 6     Indah banget air terjunnya, apalagi sehabis hu...
# 7     Salah satu Curug Terindah di Jawa Barat.\nBerl...
# 8             Destinasi favorit Aku nih klw ke sukabumi
# ...                                                 ...
# 1001  Beautiful place, debit airnya pas dan  airnya ...
# 1002  (Diterjemahkan oleh Google) Indaah\n\n(Asli)\n...
# ...

# %%
data
# Out:
#                                 nama  bintang  \
# 0                      irsadul fuadi        5
# 1                       Ahmad Ridwan        5
# 2               taruli basa christin        5
# 3                  ni komang suryati        5
# 4     Anastasia Meirina Udayani Lumy        5
# ...                              ...      ...
# 1005               Sevirianti Astuti        4
# 1006                      om ganteng        5
# 1007                     Aldi Ismaya        4
# 1008                   Muhamad Dendi        5
# 1009                 Andrian Purnama        5
#
#                                                komentar
# 0                                                   NaN
# 1                                                   NaN
# 2     Bagus air terjun nya bisa berenang luas tempat...
# 3     2 minggu lalu abis kena bencana air bah, bangu...
# 4                                                   NaN
# ...                                                 ...
# ...
